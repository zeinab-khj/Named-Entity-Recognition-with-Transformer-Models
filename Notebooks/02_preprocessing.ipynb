# %%
from datasets import load_dataset
from google.colab import drive
drive.mount('/drive')

Coll_Dataset = load_dataset(
   "csv",
   data_files=["/drive/MyDrive/Start_LLM/Coll_Dataset.csv"]
)
# Out:
# Drive already mounted at /drive; to attempt to forcibly remount, call drive.mount("/drive", force_remount=True).
# Generating train split: 0 examples [00:00, ? examples/s]

# %%
train_dataset = Coll_Dataset['train']
train_dataset
# Out:
# Dataset({
#     features: ['Sentence_ID', 'Full_Sentence', 'Word', 'NER_Tag'],
#     num_rows: 14041
# })

# %%
train_dataset[0]
# Out:
# {'Sentence_ID': 0,
#  'Full_Sentence': 'EU rejects German call to boycott British lamb .',
#  'Word': "['EU', 'rejects', 'German', 'call', 'to', 'boycott', 'British', 'lamb', '.']",
#  'NER_Tag': "['B-ORG', 'O', 'B-MISC', 'O', 'O', 'O', 'B-MISC', 'O', 'O']"}

# %%
from sklearn.model_selection import train_test_split

dataset_split = train_dataset.train_test_split(test_size=0.2, seed=42)

# %%
dataset_split["validation"] = dataset_split["test"]
del dataset_split["test"]
dataset_split
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['Sentence_ID', 'Full_Sentence', 'Word', 'NER_Tag'],
#         num_rows: 11232
#     })
#     validation: Dataset({
#         features: ['Sentence_ID', 'Full_Sentence', 'Word', 'NER_Tag'],
#         num_rows: 2809
#     })
# })
